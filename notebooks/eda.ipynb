# %% [markdown]
# # EDA Notebook

# %% [markdown]
# ## 1. Importar librerías necesarias
# Importar pandas, numpy, matplotlib y seaborn para el análisis y visualización de datos.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# c:\Users\unaii\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\_statistics.py:32: UserWarning: A NumPy version >=1.22.4 and <2.3.0 is required for this version of SciPy (detected version 2.4.2)
#   from scipy.stats import gaussian_kde

# %% [markdown]
# ## 2. Cargar el archivo CSV
# Solicitar al usuario la ruta del archivo .csv y cargarlo en un DataFrame de pandas.

# %%
# Change this path to point to your data file
file_path = '../data/raw/mental_health_burnout_tech_2026.csv'
df = pd.read_csv(file_path)

# %% [markdown]
# ## 3. Visualizar las primeras filas del dataset
# Mostrar las primeras filas del DataFrame usando head() para obtener una vista general de los datos.

# %%
df.head()
# Out:
#    employee_id  age             gender country              job_role  \
# 0            1   33               Male   India     Software Engineer
# 1            2   24         Non-binary     USA  Full Stack Developer
# 2            3   36  Prefer not to say     USA     Software Engineer
# 3            4   38         Non-binary     USA     Software Engineer
# 4            5   22         Non-binary  France           ML Engineer
#
#   seniority_level  years_experience  years_at_company    company_size  \
# 0            Lead                11               6.4  Small (51-200)
# 1         Manager                 0               5.7  Startup (1-50)
# 2            Lead                14               5.6  Mid (201-1000)
# 3            Lead                14               1.2  Mid (201-1000)
# 4          Junior                 0               3.0  Small (51-200)
#
#           industry  ... autonomy_score  stress_score  burnout_score  \
# 0  Healthcare Tech  ...            6.1          10.0           10.0
# 1          Fintech  ...            5.4           9.3            7.0
# 2          Fintech  ...            4.1           8.9            8.5
# 3     SaaS / Cloud  ...            7.3          10.0           10.0
# 4  AI / ML Startup  ...            4.4           7.7            5.4
#
#    phq9_score              phq9_category  gad7_score     gad7_category  \
# 0          19  Moderately Severe (15-19)          12  Moderate (10-14)
# 1           8                 Mild (5-9)           6        Mild (5-9)
# 2           8                 Mild (5-9)           9        Mild (5-9)
# 3          14           Moderate (10-14)          11  Moderate (10-14)
# 4           8                 Mild (5-9)           0     Minimal (0-4)
#
#    burnout_level  seeks_mental_health_support  job_change_intention
# 0         Severe                            1                     1
# 1           High                            1                     1
# 2         Severe                            0                     1
# 3         Severe                            0                     1
# 4       Moderate                            1                     0
#
# [5 rows x 36 columns]

# %% [markdown]
# ## 4. Explorar información general del dataset
# Utilizar info() y shape para mostrar información sobre el número de filas, columnas y tipos de datos.

# %%
df.info()
print(f"Número de filas: {df.shape[0]}")
print(f"Número de columnas: {df.shape[1]}")
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   employee_id                  100000 non-null  int64
#  1   age                          100000 non-null  int64
#  2   gender                       100000 non-null  str
#  3   country                      100000 non-null  str
#  4   job_role                     100000 non-null  str
#  5   seniority_level              100000 non-null  str
#  6   years_experience             100000 non-null  int64
#  7   years_at_company             100000 non-null  float64
#  8   company_size                 100000 non-null  str
#  9   industry                     100000 non-null  str
#  10  work_mode                    100000 non-null  str
#  11  salary_usd                   100000 non-null  int64
#  12  work_hours_per_week          100000 non-null  int64
#  13  meetings_per_day             100000 non-null  float64
#  14  team_size                    100000 non-null  int64
#  15  sleep_hours_per_night        100000 non-null  float64
#  16  exercise_days_per_week       100000 non-null  int64
#  17  vacation_days_taken          100000 non-null  int64
#  18  therapy_access               100000 non-null  int64
#  19  uses_therapy                 100000 non-null  int64
#  20  ai_tools_daily               100000 non-null  int64
#  21  manager_support_score        100000 non-null  float64
#  22  work_life_balance_score      100000 non-null  float64
#  23  job_satisfaction_score       100000 non-null  float64
#  24  social_support_score         100000 non-null  float64
#  25  deadline_pressure_score      100000 non-null  float64
#  26  autonomy_score               100000 non-null  float64
#  27  stress_score                 100000 non-null  float64
#  28  burnout_score                100000 non-null  float64
#  29  phq9_score                   100000 non-null  int64
#  30  phq9_category                100000 non-null  str
#  31  gad7_score                   100000 non-null  int64
#  32  gad7_category                100000 non-null  str
#  33  burnout_level                100000 non-null  str
#  34  seeks_mental_health_support  100000 non-null  int64
#  35  job_change_intention         100000 non-null  int64
# dtypes: float64(11), int64(15), str(10)
# memory usage: 27.5 MB
# Número de filas: 100000
# Número de columnas: 36

# %% [markdown]
# ## 5. Describir variables numéricas y categóricas
# Usar describe() para variables numéricas y value_counts() para variables categóricas.

# %%
# Numerical variables
df.describe()
# Out:
#          employee_id            age  years_experience  years_at_company  \
# count  100000.000000  100000.000000     100000.000000     100000.000000
# mean    50000.500000      31.305670          9.343690          2.492581
# std     28867.657797       6.427924          6.401543          2.450426
# min         1.000000      22.000000          0.000000          0.100000
# 25%     25000.750000      26.000000          4.000000          0.700000
# 50%     50000.500000      31.000000          9.000000          1.700000
# 75%     75000.250000      36.000000         14.000000          3.500000
# max    100000.000000      55.000000         25.000000         15.000000
#
#           salary_usd  work_hours_per_week  meetings_per_day      team_size  \
# count  100000.000000        100000.000000     100000.000000  100000.000000
# mean    83285.490230            47.104080          4.162244      18.009650
# std     39392.584827             5.246902          1.937849      12.607473
# min     40000.000000            35.000000          0.000000       2.000000
# 25%     46018.250000            44.000000          2.800000       8.000000
# 50%     76630.500000            47.000000          4.000000      16.000000
# 75%    109113.000000            51.000000          5.400000      25.000000
# max    267961.000000            72.000000         12.000000      59.000000
#
#        sleep_hours_per_night  exercise_days_per_week  ...  \
# count          100000.000000           100000.000000  ...
# mean                6.102392                2.968730  ...
# std                 0.998808                1.772762  ...
# min                 3.000000                0.000000  ...
# 25%                 5.400000                2.000000  ...
# 50%                 6.100000                3.000000  ...
# 75%                 6.800000                4.000000  ...
# max                10.000000                7.000000  ...
#
#        job_satisfaction_score  social_support_score  deadline_pressure_score  \
# count           100000.000000         100000.000000            100000.000000
# mean                 4.834823              5.383951                 6.385095
# std                  1.920796              1.832774                 1.769242
# min                  1.000000              1.000000                 1.000000
# 25%                  3.500000              4.100000                 5.200000
# 50%                  4.800000              5.400000                 6.400000
# 75%                  6.200000              6.600000                 7.600000
# max                 10.000000             10.000000                10.000000
#
#        autonomy_score   stress_score  burnout_score    phq9_score  \
# count   100000.000000  100000.000000  100000.000000  100000.00000
# mean         5.836528       7.055399       5.401675       6.27194
# std          1.836491       2.128530       2.668425       4.95427
# min          1.000000       1.000000       0.000000       0.00000
# 25%          4.600000       5.500000       3.500000       2.00000
# 50%          5.800000       7.100000       5.400000       6.00000
# 75%          7.100000       8.900000       7.400000      10.00000
# max         10.000000      10.000000      10.000000      27.00000
#
#           gad7_score  seeks_mental_health_support  job_change_intention
# count  100000.000000                100000.000000         100000.000000
# mean        5.118920                     0.497890              0.320020
# std         4.007513                     0.499998              0.466486
# min         0.000000                     0.000000              0.000000
# 25%         2.000000                     0.000000              0.000000
# 50%         5.000000                     0.000000              0.000000
# 75%         8.000000                     1.000000              1.000000
# max        21.000000                     1.000000              1.000000
#
# [8 rows x 26 columns]

# %%
# Categorical values (Company size)
df['company_size'].value_counts()
# Out:
# company_size
# Mid (201-1000)        25062
# Large (1001-5000)     22027
# Startup (1-50)        19771
# Small (51-200)        18067
# Enterprise (5000+)    15073
# Name: count, dtype: int64

# %%
# Categorical values (Age)
df['age'].value_counts()
# Out:
# age
# 22    11385
# 31     5846
# 30     5706
# 29     5539
# 32     5529
# 33     5371
# 34     5277
# 28     5163
# 27     4838
# 35     4751
# 26     4435
# 36     4241
# 25     3966
# 37     3961
# 24     3438
# 38     3429
# 39     2942
# 23     2925
# 40     2435
# 41     2131
# 42     1643
# 43     1237
# 44     1061
# 45      784
# 46      590
# 47      410
# 48      316
# 49      231
# 50      153
# 51      100
# 52       55
# 53       50
# 55       39
# 54       23
# Name: count, dtype: int64

# %%
# Categorical values (Burnout level)
df['burnout_level'].value_counts()
# Out:
# burnout_level
# Severe      28576
# Moderate    26255
# Low         25807
# High        19362
# Name: count, dtype: int64

# %%
# Categorical values (Gender)
df['gender'].value_counts()
# Out:
# gender
# Male                 65243
# Female               29759
# Non-binary            3994
# Prefer not to say     1004
# Name: count, dtype: int64

# %%
# Categorical values (Country)
df['country'].value_counts()
# Out:
# country
# USA            31966
# India          21998
# UK              9939
# Canada          7940
# Germany         7099
# Australia       6169
# Brazil          4050
# Netherlands     3956
# Singapore       3947
# France          2936
# Name: count, dtype: int64

# %% [markdown]
# ## 6. Visualizar valores nulos y duplicados
# Identificar y visualizar la cantidad de valores nulos y filas duplicadas en el dataset.

# %%
# Null values
df.isnull().sum()
# Out:
# employee_id                    0
# age                            0
# gender                         0
# country                        0
# job_role                       0
# seniority_level                0
# years_experience               0
# years_at_company               0
# company_size                   0
# industry                       0
# work_mode                      0
# salary_usd                     0
# work_hours_per_week            0
# meetings_per_day               0
# team_size                      0
# sleep_hours_per_night          0
# exercise_days_per_week         0
# vacation_days_taken            0
# therapy_access                 0
# uses_therapy                   0
# ai_tools_daily                 0
# manager_support_score          0
# work_life_balance_score        0
# job_satisfaction_score         0
# social_support_score           0
# deadline_pressure_score        0
# autonomy_score                 0
# stress_score                   0
# burnout_score                  0
# phq9_score                     0
# phq9_category                  0
# gad7_score                     0
# gad7_category                  0
# burnout_level                  0
# seeks_mental_health_support    0
# job_change_intention           0
# dtype: int64

# %%
# Duplicated rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## 7. Análisis univariado de variables categóricas
# Realizar gráficos de barras para analizar la frecuencia de las variables categóricas.

# %%
# Bar plot for age distribution
df['age'].value_counts().plot(kind='bar')
plt.show()

# %%
# Bar plot for gender distribution
df['gender'].value_counts().plot(kind='bar')
plt.show()

# %%
# Bar plot for country distribution
df['country'].value_counts().plot(kind='bar')
plt.show()

# %%
# Bar plot for burnout level distribution
df['burnout_level'].value_counts().plot(kind='bar')
plt.show()

# %%
# Bar plot for company size distribution
df['company_size'].value_counts().plot(kind='bar')
plt.show()

# %% [markdown]
# ## 8. Análisis bivariado entre variables
# Explorar relaciones entre variables numéricas y categóricas mediante scatterplots y tablas cruzadas.

# %%
# Crosstab for two categorical variables   
pd.crosstab(df['age'], df['burnout_level'])
# Out:
# burnout_level  High   Low  Moderate  Severe
# age
# 22             2148  2945      2994    3298
# 23              590   789       745     801
# 24              692   878       877     991
# 25              810  1005      1004    1147
# 26              854  1127      1168    1286
# 27              912  1319      1231    1376
# 28             1011  1313      1405    1434
# 29             1055  1447      1471    1566
# 30             1116  1489      1473    1628
# 31             1092  1510      1524    1720
# 32             1097  1385      1497    1550
# 33             1088  1342      1391    1550
# 34              980  1321      1396    1580
# 35              927  1239      1250    1335
# 36              870  1092      1080    1199
# 37              782  1008      1046    1125
# 38              666   851       912    1000
# 39              569   811       737     825
# 40              465   594       662     714
# 41              400   573       582     576
# 42              300   433       456     454
# 43              234   336       326     341
# 44              208   270       305     278
# 45              143   202       207     232
# 46              112   162       157     159
# 47               78   101       111     120
# 48               43    83        84     106
# 49               43    68        56      64
# 50               25    38        38      52
# 51               20    33        26      21
# 52               11    14        15      15
# 53                8    12        17      13
# 54                5     7         3       8
# 55                8    10         9      12

# %%
# Crosstab for two categorical variables   
pd.crosstab(df['gender'], df['burnout_level'])
# Out:
# burnout_level       High    Low  Moderate  Severe
# gender
# Female              5881   7244      7759    8875
# Male               12413  17327     17241   18262
# Non-binary           870    951       999    1174
# Prefer not to say    198    285       256     265

# %%
# Crosstab for two categorical variables   
pd.crosstab(df['country'], df['burnout_level'])
# Out:
# burnout_level  High   Low  Moderate  Severe
# country
# Australia      1139  1564      1656    1810
# Brazil          771  1048      1113    1118
# Canada         1525  2027      2144    2244
# France          558   742       789     847
# Germany        1442  1828      1785    2044
# India          4275  5771      5749    6203
# Netherlands     775  1045      1028    1108
# Singapore       728  1037      1046    1136
# UK             1941  2552      2569    2877
# USA            6208  8193      8376    9189

# %%
# Crosstab for two categorical variables   
pd.crosstab(df['company_size'], df['burnout_level'])
# Out:
# burnout_level       High   Low  Moderate  Severe
# company_size
# Enterprise (5000+)  2886  3914      3969    4304
# Large (1001-5000)   4355  5643      5734    6295
# Mid (201-1000)      4829  6534      6557    7142
# Small (51-200)      3524  4573      4760    5210
# Startup (1-50)      3768  5143      5235    5625
